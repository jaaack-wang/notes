# %%
import pandas as pd
from langdetect import detect

# %%
def _extract(df, conds):    
    cond = []
    for k, v in conds.items():
        cond.append(df[k] == v)

    cond = list(map(all, zip(*cond)))
    out = df[cond]
    return out

# %%
filenames = ["filtered_negative_case_timeslice1.jsonl", 
             "filtered_negative_case_timeslice2.jsonl", 
             "positive_case_timesline1.jsonl", 
             "positive_case_timeslice2.jsonl"]

df_neg1 = pd.read_json(filenames[0], lines=True)
df_neg2 = pd.read_json(filenames[1], lines=True)
df_pos1 = pd.read_json(filenames[2], lines=True)
df_pos2 = pd.read_json(filenames[3], lines=True)

dfs = [df_neg1, df_neg2, df_pos1, df_pos2]

# %% [markdown]
# # Translation errors

# %% [markdown]
# ### Evaluation of the detection ability of `detect`
#
# - all above the random baselines: always guessing the most likely class

# %%
def lang_detect(text):
    if text == None:
        return None
        
    try: x = detect(text)
    except: x = "NA"
    
    return {"en": "English", "fr": "French"}.get(x, x)

# %%
for df, fname in zip(dfs, filenames):
    df["detected lang"] = df["contentText"].apply(lang_detect)
    accu = (df["detected lang"] == df["language"]).sum() / len(df)
    
    print(f"Language detection accuracy for {fname} is {accu}")
# Out:
# Language detection accuracy for filtered_negative_case_timeslice1.jsonl is 0.979515588765782
# Language detection accuracy for filtered_negative_case_timeslice2.jsonl is 0.9839743589743589
# Language detection accuracy for positive_case_timesline1.jsonl is 0.984081041968162
# Language detection accuracy for positive_case_timeslice2.jsonl is 0.9941520467836257

# %% [markdown]
# ### translatedTitle

# %%
data = []

for df, fname in zip(dfs, filenames):
    
    df["transTitleLang"] = df["translatedTitle"].apply(lang_detect)
    
    rate = (df["transTitleLang"] == "English").sum() / df["translatedTitle"].notna().sum()
    print(f"Rate of English for {fname}: {rate}")
    
    df["badTransTitle"] = df["transTitleLang"].apply(lambda x: x == "French")
    
    a = df[["title", "translatedTitle", "transTitleLang"]][df["badTransTitle"]]
    a.insert(0, "Filename", fname)
    a.insert(1, "Original Index", a.index)
    data.append(a)
# Out:
# Rate of English for filtered_negative_case_timeslice1.jsonl: 0.9445207832360014
# Rate of English for filtered_negative_case_timeslice2.jsonl: 0.9616935483870968
# Rate of English for positive_case_timesline1.jsonl: 0.976027397260274
# Rate of English for positive_case_timeslice2.jsonl: 0.9550561797752809

# %%
title_df = pd.concat(data).reset_index()

# %%
title_df
# Out:
#      index                                 Filename  Original Index  \
# 0       18  filtered_negative_case_timeslice1.jsonl              18
# 1      117  filtered_negative_case_timeslice1.jsonl             117
# 2      200  filtered_negative_case_timeslice1.jsonl             200
# 3      221  filtered_negative_case_timeslice1.jsonl             221
# 4      224  filtered_negative_case_timeslice1.jsonl             224
# ..     ...                                      ...             ...
# 125    480           positive_case_timesline1.jsonl             480
# 126    597           positive_case_timesline1.jsonl             597
# 127    133           positive_case_timeslice2.jsonl             133
# 128    153           positive_case_timeslice2.jsonl             153
# 129    454           positive_case_timeslice2.jsonl             454
#
#                                                  title  \
# 0    En direct. Présidentielle 2022 : Marine Le Pen...
# 1    [ALERTE] Russie/Ukraine… Suite/suite 14-02- 21...
# 2    [ALERTE] Russie/Ukraine… Suite/suite 14-02- 21...
# 3    [ALERTE] Russie/Ukraine… Suite/suite 1402-2022...
# 4    [ALERTE] Russie/Ukraine… Suite/suite 14-02- 21...
# ..                                                 ...
# 125  [ALERTE] Russie/Ukraine… Suite/suite 14-02- 21...
# 126  [ALERTE] Russie/Ukraine… Suite/suite sur le fo...
# 127  L’empire du mensonge en matière d’armes biolog...
# 128  @UPR_Asselineau ⚠️#Donbass - INFO CONFIRMEE -\...
# 129               France Insoumise - Quatennens, ROAT.
#
#                                        translatedTitle transTitleLang
# 0    Live. President 2022: Marine Le Pen envisages ...         French
# 1    [ALERT] Russia/Ukraine... Continue/cont'd 14-0...         French
# 2    [ALERT] Russia/Ukraine... Continue/cont'd 14-0...         French
# 3    [ALERT] Russia/Ukraine... Continue/cont'd 1402...         French
# 4    [ALERT] Russia/Ukraine... Continue/cont'd 14-0...         French
# ..                                                 ...            ...
# 125  [ALERT] Russia/Ukraine... Continue/cont'd 14-0...         French
# 126  [ALERT] Russia/Ukraine... Continue/suite on th...         French
# 127  Le empire du lie en matière d'armes biologique...         French
# 128                 @UPR_Asselineau  //t.co/nSM4lPq72f         French
# 129              France Insoumise - Quatennens, ROAT.          French
#
# [130 rows x 6 columns]

# %% [markdown]
# ### translatedContentText

# %%
data = []

for df, fname in zip(dfs, filenames):
    
    df["transTextLang"] = df["translatedContentText"].apply(lang_detect)
    rate = (df["transTextLang"] == "English").sum() / df["translatedContentText"].notna().sum()
    print(f"Rate of English for {fname}: {rate}")
    
    # df["badTransText"] = df["transTextLang"].apply(lambda x: x == "French")
    df["badTransText"] = df["transTextLang"].apply(lambda x: x not in [None, "English"])
    
    a = df[["contentText", "translatedContentText", "transTextLang"]][df["badTransText"]]
    a.insert(0, "Filename", fname)
    a.insert(1, "Original Index", a.index)
    data.append(a)
# Out:
# Rate of English for filtered_negative_case_timeslice1.jsonl: 0.9847837237134552
# Rate of English for filtered_negative_case_timeslice2.jsonl: 0.9865384615384616
# Rate of English for positive_case_timesline1.jsonl: 1.0
# Rate of English for positive_case_timeslice2.jsonl: 0.994413407821229

# %%
text_df = pd.concat(data).reset_index()
text_df
# Out:
#     index                                 Filename  Original Index  \
# 0     335  filtered_negative_case_timeslice1.jsonl             335
# 1     350  filtered_negative_case_timeslice1.jsonl             350
# 2     351  filtered_negative_case_timeslice1.jsonl             351
# 3     535  filtered_negative_case_timeslice1.jsonl             535
# 4     653  filtered_negative_case_timeslice1.jsonl             653
# ..    ...                                      ...             ...
# 92    375  filtered_negative_case_timeslice2.jsonl             375
# 93    451  filtered_negative_case_timeslice2.jsonl             451
# 94    452  filtered_negative_case_timeslice2.jsonl             452
# 95    529  filtered_negative_case_timeslice2.jsonl             529
# 96    153           positive_case_timeslice2.jsonl             153
#
#                                           contentText  \
# 0             enfonçage de porte ouverte ou truisme ?
# 1   RT @UPR_Asselineau 🚨Suite prévisible 1- le Con...
# 2   RT @UPR_Asselineau ⚠️ la Russie n'est que «pay...
# 3                              U stupid aussie wanker
# 4   Il ne se prive pas de le faire avec ceux qu’il...
# ..                                                ...
# 92                      @EmmanuelMacron Bnsoir macron
# 93  RT @UPR_Asselineau 🚨L'UKRAINE À COURT DE MUNIT...
# 94  RT @UPR_Asselineau 🚨L'UKRAINE À COURT DE MUNIT...
# 95  RT @UPR_Asselineau ▪️que les Africains rejette...
# 96  @UPR_Asselineau ⚠️#Donbass - INFO CONFIRMEE - ...
#
#                                 translatedContentText transTextLang
# 0                                Open door or truism?            nl
# 1                                  RT @UPR_Asselineau            et
# 2                                  RT @UPR_Asselineau            et
# 3                                U stupid also wanker            af
# 4   He doesn't stop doing it with people he doesn'...            af
# ..                                                ...           ...
# 92                      @EmmanuelMacron Bnsoir macron        French
# 93                                 RT @UPR_Asselineau            et
# 94                                 RT @UPR_Asselineau            et
# 95                               RT @UPR_Asselineau ▪            et
# 96                 @UPR_Asselineau  //t.co/nSM4lPq72f        French
#
# [97 rows x 6 columns]

# %%
title_df.to_csv("transTitlesInspected.csv")
text_df.to_csv("transTextsInspected.csv")
