# %%
import pandas as pd

# %%
# !ls
# Out:
# Inspection of translation.ipynb         metadata.ipynb
# data_exploration.ipynb                  positive_case_timeslice2.jsonl
# filtered_negative_case_timeslice1.jsonl positive_case_timesline1.jsonl
# filtered_negative_case_timeslice2.jsonl

# %%
def _extract(df, conds):    
    cond = []
    for k, v in conds.items():
        cond.append(df[k] == v)

    cond = list(map(all, zip(*cond)))
    out = df[cond]
    return out

# %%
filenames = ["filtered_negative_case_timeslice1.jsonl", 
             "filtered_negative_case_timeslice2.jsonl", 
             "positive_case_timesline1.jsonl", 
             "positive_case_timeslice2.jsonl"]

df_neg1 = pd.read_json(filenames[0], lines=True)
df_neg2 = pd.read_json(filenames[1], lines=True)
df_pos1 = pd.read_json(filenames[2], lines=True)
df_pos2 = pd.read_json(filenames[3], lines=True)

dfs = [df_neg1, df_neg2, df_pos1, df_pos2]

# %% [markdown]
# # Overall
#
# - Empty columns: "extraAttributes", "segments", "mentionedUsers",

# %% [markdown]
# ## Language

# %%
def num_not_na(df, col):
    return df[col].notna().sum()

# %%
data = []
col = ["# Doc", "# En Doc", "# Fr Doc", 
       "# translatedContentText (Fr->En)", "# translatedTitle (Fr->En)"]

for df in dfs:
    num_doc = len(df)
    num_en = len(df[df.language=="English"])
    num_fr = len(df[df.language=="French"])
    num_trans_text = num_not_na(df, "translatedContentText")
    num_trans_title = num_not_na(df, "translatedTitle")
    
    data.append([num_doc, num_en, num_fr, 
                 num_trans_text, num_trans_title])
    
pd.DataFrame(data, columns=col, index=filenames)
# Out:
#                                          # Doc  # En Doc  # Fr Doc  \
# filtered_negative_case_timeslice1.jsonl   7762       325      7437
# filtered_negative_case_timeslice2.jsonl    624        30       594
# positive_case_timesline1.jsonl             691       218       473
# positive_case_timeslice2.jsonl             513       237       276
#
#                                          # translatedContentText (Fr->En)  \
# filtered_negative_case_timeslice1.jsonl                              5849
# filtered_negative_case_timeslice2.jsonl                               520
# positive_case_timesline1.jsonl                                        299
# positive_case_timeslice2.jsonl                                        179
#
#                                          # translatedTitle (Fr->En)
# filtered_negative_case_timeslice1.jsonl                        5822
# filtered_negative_case_timeslice2.jsonl                         496
# positive_case_timesline1.jsonl                                  292
# positive_case_timeslice2.jsonl                                  178

# %% [markdown]
# ## Mediatype

# %%
data = []
col = ["# Doc", "# News", "# Blog", "# Twitter", 
       "# Reddit", "# Forum", "# Other"]

types = ["News", "Blog", "Twitter", 
         "Reddit", "Forum", "Other"]

for df in dfs:
    sub = [len(df)]
    dic = df[["mediaType", "contentText"]].groupby(["mediaType"]).count().to_dict()["contentText"]
    
    for t in types:
        sub.append(dic.get(t, 0))
    data.append(sub)

pd.DataFrame(data, columns=col, index=filenames)
# Out:
#                                          # Doc  # News  # Blog  # Twitter  \
# filtered_negative_case_timeslice1.jsonl   7762    1715     655       2846
# filtered_negative_case_timeslice2.jsonl    624     126      65        308
# positive_case_timesline1.jsonl             691     127     326         80
# positive_case_timeslice2.jsonl             513      78     305         46
#
#                                          # Reddit  # Forum  # Other
# filtered_negative_case_timeslice1.jsonl       370     2032      144
# filtered_negative_case_timeslice2.jsonl        44       75        6
# positive_case_timesline1.jsonl                  5      143       10
# positive_case_timeslice2.jsonl                  0       80        4

# %% [markdown]
# ### mediaType word count

# %%
data = []

for df, fname in zip(dfs, filenames):
    df["wordCount"] = df["contentText"].apply(lambda x: len(x.split()))
    res = df[["wordCount", "mediaType"]].groupby(["mediaType"])["wordCount"]
    res = res.describe().to_dict()
    
    sub = []
    mean, std = res["mean"], res["std"]
    
    for t in types:
        m = str(round(mean.get(t, 0), 2))
        s = str(round(std.get(t, 0), 2))
        sub.append(m + " + " + s)
    
    data.append(sub)

print("Word counts: Mean + Std")
pd.DataFrame(data, columns=col[1:], index=filenames)
# Out:
# Word counts: Mean + Std
#                                                     # News  \
# filtered_negative_case_timeslice1.jsonl    628.64 + 813.18
# filtered_negative_case_timeslice2.jsonl    682.71 + 653.37
# positive_case_timesline1.jsonl           1546.94 + 1715.71
# positive_case_timeslice2.jsonl            1502.83 + 1130.1
#
#                                                      # Blog      # Twitter  \
# filtered_negative_case_timeslice1.jsonl   1089.39 + 2408.32  27.36 + 14.47
# filtered_negative_case_timeslice2.jsonl    683.17 + 1270.45  31.77 + 14.63
# positive_case_timesline1.jsonl           8237.43 + 11017.45   27.99 + 14.7
# positive_case_timeslice2.jsonl           11735.17 + 10638.1  32.46 + 13.43
#
#                                                # Reddit           # Forum  \
# filtered_negative_case_timeslice1.jsonl  75.46 + 145.76   335.92 + 599.99
# filtered_negative_case_timeslice2.jsonl    67.16 + 86.4   290.37 + 357.86
# positive_case_timesline1.jsonl             169.2 + 85.7  856.79 + 1522.62
# positive_case_timeslice2.jsonl                    0 + 0  913.61 + 1510.26
#
#                                                   # Other
# filtered_negative_case_timeslice1.jsonl     90.27 + 95.98
# filtered_negative_case_timeslice2.jsonl    187.67 + 149.6
# positive_case_timesline1.jsonl           1450.0 + 4094.06
# positive_case_timeslice2.jsonl             289.0 + 183.58

# %%
print("Word counts: Detailed", end="\n\n\n")

for df, fname in zip(dfs, filenames):
    df["wordCount"] = df["contentText"].apply(lambda x: len(x.split()))
    res = df[["wordCount", "mediaType"]].groupby(["mediaType"])["wordCount"].describe()
    res.drop(columns=["25%", "75%"], inplace=True)
    print(fname, end="\n\n")
    print(res, end="\n\n\n\n")
# Out:
# Word counts: Detailed
#
#
# filtered_negative_case_timeslice1.jsonl
#
#             count         mean          std   min    50%      max
# mediaType
# Blog        655.0  1089.389313  2408.320105  10.0  302.0  22225.0
# Forum      2032.0   335.915354   599.990990   1.0  154.0   7352.0
# News       1715.0   628.642566   813.179788  12.0  452.0  12180.0
# Other       144.0    90.270833    95.979326   8.0   60.5    659.0
# Reddit      370.0    75.464865   145.764930   1.0   33.0   1798.0
# Twitter    2846.0    27.361560    14.466457   1.0   27.0     61.0
#
#
#
# filtered_negative_case_timeslice2.jsonl
#
#            count        mean          std   min    50%     max
# mediaType
# Blog        65.0  683.169231  1270.445561  15.0   83.0  5793.0
# Forum       75.0  290.373333   357.855919  10.0  179.0  1655.0
# News       126.0  682.706349   653.369360  36.0  513.5  4084.0
# Other        6.0  187.666667   149.603030  56.0  152.5   434.0
# Reddit      44.0   67.159091    86.400620   6.0   40.0   421.0
# Twitter    308.0   31.769481    14.631481   2.0   36.5    53.0
#
#
#
# positive_case_timesline1.jsonl
#
#            count         mean           std   min     50%      max
# mediaType
# Blog       326.0  8237.432515  11017.449118  23.0  2536.0  55405.0
# Forum      143.0   856.790210   1522.615961  29.0   467.0  11752.0
# News       127.0  1546.937008   1715.709885  74.0  1161.0  11042.0
# Other       10.0  1450.000000   4094.058541  33.0   127.0  13093.0
# Reddit       5.0   169.200000     85.701225  80.0   162.0    259.0
# Twitter     80.0    27.987500     14.695641   1.0    33.0     58.0
#
#
#
# positive_case_timeslice2.jsonl
#
#            count          mean           std    min     50%      max
# mediaType
# Blog       305.0  11735.170492  10638.098946   44.0  9239.0  85007.0
# Forum       80.0    913.612500   1510.256307   41.0   413.0   9463.0
# News        78.0   1502.833333   1130.101759  180.0  1060.0   7430.0
# Other        4.0    289.000000    183.577413  148.0   227.5    553.0
# Twitter     46.0     32.456522     13.432476    4.0    35.5     52.0

# %% [markdown]
# # English mediatype

# %%
data = []
col = ["# Doc", "# News", "# Blog", "# Twitter", 
       "# Reddit", "# Forum", "# Other"]

types = ["News", "Blog", "Twitter", 
         "Reddit", "Forum", "Other"]

for df in dfs:
    df = df[df["language"] == "English"]
    sub = [len(df)]
    dic = df[["mediaType", "contentText"]].groupby(["mediaType"]).count().to_dict()["contentText"]
    
    for t in types:
        sub.append(dic.get(t, 0))
    data.append(sub)
    
    
pd.DataFrame(data, columns=col, index=filenames)
# Out:
#                                          # Doc  # News  # Blog  # Twitter  \
# filtered_negative_case_timeslice1.jsonl    325       1      27        276
# filtered_negative_case_timeslice2.jsonl     30       0       0         28
# positive_case_timesline1.jsonl             218       1     161         32
# positive_case_timeslice2.jsonl             237       0     214          9
#
#                                          # Reddit  # Forum  # Other
# filtered_negative_case_timeslice1.jsonl         7       12        2
# filtered_negative_case_timeslice2.jsonl         2        0        0
# positive_case_timesline1.jsonl                  2       21        1
# positive_case_timeslice2.jsonl                  0       14        0

# %% [markdown]
# ### mediaType word count
#
# - Turns out that for English, the length of each News article is fixed.

# %%
data = []

for df, fname in zip(dfs, filenames):
    df["wordCount"] = df["contentText"].apply(lambda x: len(x.split()))
    df = df[df["language"] == "English"]
    
    res = df[["wordCount", "mediaType"]].groupby(["mediaType"])["wordCount"]
    res = res.describe().to_dict()
    
    sub = []
    mean, std = res["mean"], res["std"]
    
    for t in types:
        m = str(round(mean.get(t, 0), 2))
        s = str(round(std.get(t, 0), 2))
        sub.append(m + " + " + s)
    
    data.append(sub)

print("Word counts: Mean + Std")
pd.DataFrame(data, columns=col[1:], index=filenames)
# Out:
# Word counts: Mean + Std
#                                                # News               # Blog  \
# filtered_negative_case_timeslice1.jsonl   538.0 + nan    4841.44 + 5780.53
# filtered_negative_case_timeslice2.jsonl         0 + 0                0 + 0
# positive_case_timesline1.jsonl           1268.0 + nan  15085.01 + 12208.57
# positive_case_timeslice2.jsonl                  0 + 0   15884.4 + 10117.68
#
#                                              # Twitter         # Reddit  \
# filtered_negative_case_timeslice1.jsonl  21.53 + 14.79  255.57 + 211.55
# filtered_negative_case_timeslice2.jsonl  22.46 + 15.13   310.0 + 156.98
# positive_case_timesline1.jsonl            24.44 + 16.0     126.5 + 50.2
# positive_case_timeslice2.jsonl           27.78 + 16.49            0 + 0
#
#                                                    # Forum        # Other
# filtered_negative_case_timeslice1.jsonl  1265.83 + 1833.61  318.5 + 62.93
# filtered_negative_case_timeslice2.jsonl              0 + 0          0 + 0
# positive_case_timesline1.jsonl            2855.9 + 3250.23  13093.0 + nan
# positive_case_timeslice2.jsonl           2995.07 + 2666.15          0 + 0

# %%
print("Word counts: Detailed", end="\n\n\n")

for df, fname in zip(dfs, filenames):
    df["wordCount"] = df["contentText"].apply(lambda x: len(x.split()))
    df = df[df["language"] == "English"]
    
    res = df[["wordCount", "mediaType"]].groupby(["mediaType"])["wordCount"].describe()
    res.drop(columns=["25%", "75%"], inplace=True)
    print(fname, end="\n\n")
    print(res, end="\n\n\n\n")
# Out:
# Word counts: Detailed
#
#
# filtered_negative_case_timeslice1.jsonl
#
#            count         mean          std    min     50%      max
# mediaType
# Blog        27.0  4841.444444  5780.527460   53.0  2357.0  22225.0
# Forum       12.0  1265.833333  1833.614505  152.0   713.0   6853.0
# News         1.0   538.000000          NaN  538.0   538.0    538.0
# Other        2.0   318.500000    62.932504  274.0   318.5    363.0
# Reddit       7.0   255.571429   211.552875   19.0   317.0    575.0
# Twitter    276.0    21.528986    14.788050    1.0    23.0     57.0
#
#
#
# filtered_negative_case_timeslice2.jsonl
#
#            count        mean         std    min    50%    max
# mediaType
# Reddit       2.0  310.000000  156.977705  199.0  310.0  421.0
# Twitter     28.0   22.464286   15.127806    2.0   19.0   43.0
#
#
#
# positive_case_timesline1.jsonl
#
#            count          mean           std      min      50%      max
# mediaType
# Blog       161.0  15085.006211  12208.566244    432.0  11363.0  55405.0
# Forum       21.0   2855.904762   3250.225052    350.0   1514.0  11752.0
# News         1.0   1268.000000           NaN   1268.0   1268.0   1268.0
# Other        1.0  13093.000000           NaN  13093.0  13093.0  13093.0
# Reddit       2.0    126.500000     50.204581     91.0    126.5    162.0
# Twitter     32.0     24.437500     16.003906      1.0     29.5     42.0
#
#
#
# positive_case_timeslice2.jsonl
#
#            count          mean           std    min      50%      max
# mediaType
# Blog       214.0  15884.401869  10117.677540  584.0  13933.5  85007.0
# Forum       14.0   2995.071429   2666.154317  607.0   2310.5   9463.0
# Twitter      9.0     27.777778     16.490738    4.0     24.0     50.0

# %% [markdown]
# # French mediatype

# %%
data = []
col = ["# Doc", "# News", "# Blog", "# Twitter", 
       "# Reddit", "# Forum", "# Other"]

types = ["News", "Blog", "Twitter", 
         "Reddit", "Forum", "Other"]

for df in dfs:
    df = df[df["language"] == "French"]
    sub = [len(df)]
    dic = df[["mediaType", "contentText"]].groupby(["mediaType"]).count().to_dict()["contentText"]
    
    for t in types:
        sub.append(dic.get(t, 0))
    data.append(sub)
    

pd.DataFrame(data, columns=col, index=filenames)
# Out:
#                                          # Doc  # News  # Blog  # Twitter  \
# filtered_negative_case_timeslice1.jsonl   7437    1714     628       2570
# filtered_negative_case_timeslice2.jsonl    594     126      65        280
# positive_case_timesline1.jsonl             473     126     165         48
# positive_case_timeslice2.jsonl             276      78      91         37
#
#                                          # Reddit  # Forum  # Other
# filtered_negative_case_timeslice1.jsonl       363     2020      142
# filtered_negative_case_timeslice2.jsonl        42       75        6
# positive_case_timesline1.jsonl                  3      122        9
# positive_case_timeslice2.jsonl                  0       66        4

# %% [markdown]
# ### mediaType word count

# %%
data = []

for df, fname in zip(dfs, filenames):
    df["wordCount"] = df["contentText"].apply(lambda x: len(x.split()))
    df = df[df["language"] == "French"]
    
    res = df[["wordCount", "mediaType"]].groupby(["mediaType"])["wordCount"]
    res = res.describe().to_dict()
    
    sub = []
    mean, std = res["mean"], res["std"]
    
    for t in types:
        m = str(round(mean.get(t, 0), 2))
        s = str(round(std.get(t, 0), 2))
        sub.append(m + " + " + s)
    
    data.append(sub)

print("Word counts: Mean + Std")
pd.DataFrame(data, columns=col[1:], index=filenames)
# Out:
# Word counts: Mean + Std
#                                                     # News             # Blog  \
# filtered_negative_case_timeslice1.jsonl     628.7 + 813.41   928.07 + 2007.95
# filtered_negative_case_timeslice2.jsonl    682.71 + 653.37   683.17 + 1270.45
# positive_case_timesline1.jsonl           1549.15 + 1722.38  1555.86 + 2046.22
# positive_case_timeslice2.jsonl            1502.83 + 1130.1  1977.64 + 1669.52
#
#                                              # Twitter         # Reddit  \
# filtered_negative_case_timeslice1.jsonl  27.99 + 14.29    71.99 + 142.4
# filtered_negative_case_timeslice2.jsonl   32.7 + 14.28     55.6 + 64.92
# positive_case_timesline1.jsonl           30.35 + 13.41  197.67 + 101.93
# positive_case_timeslice2.jsonl           33.59 + 12.58            0 + 0
#
#                                                  # Forum          # Other
# filtered_negative_case_timeslice1.jsonl  330.39 + 581.93    87.06 + 92.55
# filtered_negative_case_timeslice2.jsonl  290.37 + 357.86   187.67 + 149.6
# positive_case_timesline1.jsonl           512.68 + 402.02  156.33 + 169.64
# positive_case_timeslice2.jsonl           472.09 + 468.38   289.0 + 183.58

# %%
print("Word counts: Detailed", end="\n\n\n")

for df, fname in zip(dfs, filenames):
    df["wordCount"] = df["contentText"].apply(lambda x: len(x.split()))
    df = df[df["language"] == "French"]
    
    res = df[["wordCount", "mediaType"]].groupby(["mediaType"])["wordCount"].describe()
    res.drop(columns=["25%", "75%"], inplace=True)
    print(fname, end="\n\n")
    print(res, end="\n\n\n\n")
# Out:
# Word counts: Detailed
#
#
# filtered_negative_case_timeslice1.jsonl
#
#             count        mean          std   min    50%      max
# mediaType
# Blog        628.0  928.074841  2007.951096  10.0  259.0  18743.0
# Forum      2020.0  330.391089   581.928555   1.0  153.0   7352.0
# News       1714.0  628.695449   813.414159  12.0  451.0  12180.0
# Other       142.0   87.056338    92.549222   8.0   60.0    659.0
# Reddit      363.0   71.991736   142.397787   1.0   33.0   1798.0
# Twitter    2570.0   27.987938    14.293545   1.0   28.0     61.0
#
#
#
# filtered_negative_case_timeslice2.jsonl
#
#            count        mean          std   min    50%     max
# mediaType
# Blog        65.0  683.169231  1270.445561  15.0   83.0  5793.0
# Forum       75.0  290.373333   357.855919  10.0  179.0  1655.0
# News       126.0  682.706349   653.369360  36.0  513.5  4084.0
# Other        6.0  187.666667   149.603030  56.0  152.5   434.0
# Reddit      42.0   55.595238    64.919485   6.0   40.0   368.0
# Twitter    280.0   32.700000    14.277937   2.0   37.0    53.0
#
#
#
# positive_case_timesline1.jsonl
#
#            count         mean          std   min     50%      max
# mediaType
# Blog       165.0  1555.860606  2046.222745  23.0   898.0  11083.0
# Forum      122.0   512.680328   402.018836  29.0   440.0   2261.0
# News       126.0  1549.150794  1722.376935  74.0  1141.5  11042.0
# Other        9.0   156.333333   169.642271  33.0   116.0    590.0
# Reddit       3.0   197.666667   101.932985  80.0   254.0    259.0
# Twitter     48.0    30.354167    13.407666   3.0    33.0     58.0
#
#
#
# positive_case_timeslice2.jsonl
#
#            count         mean          std    min     50%     max
# mediaType
# Blog        91.0  1977.637363  1669.515256   44.0  1620.0  7418.0
# Forum       66.0   472.090909   468.375350   41.0   355.5  3275.0
# News        78.0  1502.833333  1130.101759  180.0  1060.0  7430.0
# Other        4.0   289.000000   183.577413  148.0   227.5   553.0
# Twitter     37.0    33.594595    12.581864    9.0    37.0    52.0
